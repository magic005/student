// %% [raw]
// ---
// layout: post
// toc: true
// title: AP CSA Variables and Data Types Topic Check
// description: Targeted variables and data types MCQ reflection with Java repair code.
// permalink: /ap-prep/mcq/variables-data-types/
// comments: true
// ---

// %% [markdown]
// # Variables and Data Types Topic Check
//
// Result: **96%**. Source trace: College Board assignment screenshot in `ref_for_ap_prep`. I treated this as a targeted check on assignment, primitive types, integer division, casting, and how a variable changes over time.

// %%
public class VariablesAndTypesDrill {
    public static double average(int a, int b) {
        return (a + b) / 2.0;
    }

    public static int onesDigit(int value) {
        return value % 10;
    }

    public static int afterCompoundUpdates() {
        int x = 7;
        x += 3;
        x *= 2;
        x /= 5;
        return x;
    }
}

// %% [markdown]
// ## Reflection
//
// This tied directly to missed arithmetic-tracing questions. The repair habit was to write the type of each expression before evaluating it, especially when `int` division and `double` casting are mixed.

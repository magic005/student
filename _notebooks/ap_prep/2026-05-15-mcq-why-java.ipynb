// %% [raw]
// ---
// layout: post
// toc: true
// title: AP CSA Intro Java Topic Check
// description: Short MCQ topic reflection for intro Java concepts.
// permalink: /ap-prep/mcq/why-java/
// comments: true
// ---

// %% [markdown]
// # Intro Java Topic Check
//
// Result: **1/1 (100%)**. Source trace: College Board assignment screenshot in `ref_for_ap_prep`. This was a short check on why Java is used in AP CSA and what makes Java different from quick scripting languages: class structure, typed variables, methods, and object-oriented design.

// %%
public class IntroJavaCheck {
    private String language;
    private boolean stronglyTyped;

    public IntroJavaCheck(String language, boolean stronglyTyped) {
        this.language = language;
        this.stronglyTyped = stronglyTyped;
    }

    public String summary() {
        if (stronglyTyped) {
            return language + " uses explicit types and classes.";
        }
        return language + " is being used in a lighter scripting style.";
    }
}

// %% [markdown]
// ## Reflection
//
// This was mostly a confidence builder. The important connection to the exam was remembering that Java questions usually assume type rules, object state, and method calls are not optional details.
